# %% [markdown]
# # Similar Breakfast Cereal

# %% [markdown]
# ### Part 2: Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import data with normalized k-means clusters
cereal = pd.read_csv('norm.csv')

# %%
cereal
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0   Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 1      Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 2                    Maypo   A    H       100        4    1       0    0.0
# 3              Puffed Rice   Q    C        50        1    0       0    0.0
# 4             Puffed Wheat   Q    C        50        2    0       0    1.0
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 72  Just Right Fruit & Nut   K    C       140        3    1     170    2.0
# 73              Product 19   K    C       100        3    0     320    1.0
# 74       Total Corn Flakes   G    C       110        2    1     200    0.0
# 75       Total Raisin Bran   G    C       140        3    1     190    4.0
# 76       Total Whole Grain   G    C       100        3    1     200    3.0
#
# ...

# %%
# duplicate kmeans_norm_labels column
cereal['cluster']=cereal['kmeans_norm_labels']

# %%
cereal
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0   Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 1      Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 2                    Maypo   A    H       100        4    1       0    0.0
# 3              Puffed Rice   Q    C        50        1    0       0    0.0
# 4             Puffed Wheat   Q    C        50        2    0       0    1.0
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 72  Just Right Fruit & Nut   K    C       140        3    1     170    2.0
# 73              Product 19   K    C       100        3    0     320    1.0
# 74       Total Corn Flakes   G    C       110        2    1     200    0.0
# 75       Total Raisin Bran   G    C       140        3    1     190    4.0
# 76       Total Whole Grain   G    C       100        3    1     200    3.0
#
# ...

# %%
# Reassign cluster labels
cereal['cluster']=cereal['cluster'].replace({0:'D', 1:'A', 2:'E', 3:'B', 4:'C', 5:'F'})

# %%
cereal
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 0        Cream of Wheat (Quick)   N    H       100        3    0      80
# 9     Shredded Wheat spoon size   N    C        90        3    0       0
# 8        Shredded Wheat 'n'Bran   N    C        90        3    0       0
# 7                Shredded Wheat   N    C        80        2    0       0
# 6                Raisin Squares   K    C        90        2    0       0
# ..                          ...  ..  ...       ...      ...  ...     ...
# 71  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 72       Just Right Fruit & Nut   K    C       140        3    1     170
# 73                   Product 19   K    C       100        3    0     320
# 74            Total Corn Flakes   G    C       110        2    1     200
# 76            Total Whole Grain   G    C       100        3    1     200
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# ...

# %%
# sort clusters in alpha order
cereal = cereal.sort_values('cluster')

# %%
cereal
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 15        Cinnamon Toast Crunch   G    C       120        1    3     210
# 21               Frosted Flakes   K    C       110        1    0     200
# 11               Almond Delight   R    C       110        2    2     200
# 12      Apple Cinnamon Cheerios   G    C       110        2    2     180
# 14                 Cap'n'Crunch   Q    C       120        1    2     220
# ..                          ...  ..  ...       ...      ...  ...     ...
# 71  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 72       Just Right Fruit & Nut   K    C       140        3    1     170
# 73                   Product 19   K    C       100        3    0     320
# 74            Total Corn Flakes   G    C       110        2    1     200
# 76            Total Whole Grain   G    C       100        3    1     200
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# ...

# %% [markdown]
# #### Histograms of features for each cluster

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'calories']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Calories per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'fat']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Fat per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'potass']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Potassium per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'shelf']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Shelf Placement per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'sugars']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Sugars per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'fiber']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Fiber per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'sodium']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Sodium per Cluster', y = 1.05, size=16)

plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 6, figsize=(10,2.5), dpi=100, sharex=True, sharey=True)

colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:orange']

for i, (ax, cluster) in enumerate(zip(axes.flatten(), cereal.cluster.unique())):
    x = cereal.loc[cereal.cluster==cluster, 'protein']
    
    ax.hist(x, alpha=0.8, bins=5, density=True, stacked = True, label = str(cluster), color=colors[i])
    
    ax.set_title(cluster)

plt.suptitle('Histogram of Protein per Cluster', y = 1.05, size=16)

plt.tight_layout();
